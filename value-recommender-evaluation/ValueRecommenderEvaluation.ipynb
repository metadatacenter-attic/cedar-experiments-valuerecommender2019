# %% [markdown]
# # CEDAR's Value Recommender - Evaluation
#
# This notebook describes the steps followed to evaluate [CEDAR's Value Recommender](https://github.com/metadatacenter/cedar-docs/wiki/CEDAR-Value-Recommender).
#
# ## Step 1: Datasets download
# ### NCBI BioSample
# We downloaded the full content of the [NCBI BioSample database](https://www.ncbi.nlm.nih.gov/biosample/) from the [NCBI BioSample FTP repository](https://ftp.ncbi.nih.gov/biosample/). As a result, we obtained a ZIP file ([2018-03-09-biosample_set.xml.zip](data/samples/ncbi_samples/original/2018-03-09-biosample_set.xml.zip)) with a total of 7.8M samples in XML format. File size: 618MB compressed, 20.11GB uncompressed. These samples were downloaded on March 9, 2018.
# If you want to download the most recent content of NCBI BioSample, you can run the following code:

# %%
import urllib.request
import sys
import time
import scripts.util

url = 'https://ftp.ncbi.nih.gov/biosample/biosample_set.xml.gz'
file_name = 'tmp/biosample_set.xml.gz'
urllib.request.urlretrieve(url, file_name, reporthook=log_progress)

# %% [markdown]
# ### EBI BioSamples
# We wrote a script ([ebi_biosamples_1_download_split.py](scripts/ebi_biosamples_1_download_split.py)) to download all the biosample metadata from the [EBI BioSamples database](https://www.ebi.ac.uk/biosamples/) using the [EBI BioSamples API](https://www.ebi.ac.uk/biosamples/help/api.html), and to store the results as multiple JSON files. We obtained 4.1M samples stored as [412 JSON files](data/samples/ebi_samples/original) with 10K samples each (5.07GB in total). These samples were downloaded on March 9, 2018.

# %%
# %run ./scripts/ebi_biosamples_1_download_split # Run it again, it does not work

# %% [markdown]
# ## Step 2: Generation of template instances
#
# ### 2.1 Determine relevant attributes and create CEDAR templates
#
# #### NCBI BioSample
#
# For NCBI BioSample, we created a CEDAR template with all the attributes defined by the [NCBI BioSample Human Package v1.0](https://submit.ncbi.nlm.nih.gov/biosample/template/?package=Human.1.0&action=definition), which are: *biosample_accession, sample_name, sample_title, bioproject_accession, organism, isolate, age, biomaterial_provider, sex, tissue, cell_line, cell_subtype, cell_type, culture_collection, dev_stage, disease, disease_stage, ethnicity, health_state, karyotype, phenotype, population, race, sample_type, treatment, description*.
#
# #### EBI BioSamples
#
# The EBI BioSamples API's output format defines some top-level attributes and makes it possible to add new attributes that describe sample characteristics:
# ```
# {
#     "accession": "...",
#     "name": "...",
#     "releaseDate": "...",
#     "updateDate": "...",
#     "characteristics": { // key-value pairs (e.g., organism, age, sex, organismPart, etc.)
#     	...
#     },
#     "organization": "...",
#     "contact": "..."
# }
# ```
#
# Based on this format, we defined a metadata template containing 14 fields with general metadata about biological samples and some additional fields that capture specific characteristics of human samples: *accession, name, releaseDate, updateDate, organization, contact, organism, age, sex, organismPart, cellLine, cellType, diseaseState, ethnicity*.
#
# We focused our analysis on the subset of fields that meet two key requirements: (1) they are present in both templates and, therefore, can be used to evaluate cross-template recommendations; and (2) they contain categorical values, that is, they represent information about discrete characteristics. We selected 6 fields that met these criteria. These fields are: *sex, organism part, cell line, cell type, disease, and ethnicity*. The names used to refer to these fields in both CEDAR's NCBI BioSample template and CEDAR's EBI BioSamples template are shown in the following table:
#
# |Characteristic|NCBI BioSample attribute name|EBI BioSamples attribute name|
# |---|---|---|
# |sex|sex|sex|
# |organism part|tissue|organismPart|
# |cell line|cell_line|cellLine|
# |cell type|cell_type|cellType|
# |disease|disease|diseaseState|
# |ethnicity|ethnicity|ethnicity|

# %% [markdown]
# ### 2.2 Select samples
#
# We filtered the samples based on two criteria:
# * The sample is from "Homo sapiens" (organism=Homo sapiens).
# * The sample has non-empty values for at least 3 of the 6 fields in the previous table.
#
# #### NCBI BioSample
#
# Script used: [ncbi_biosample_1_filter.py](scripts/ncbi_biosample_1_filter.py).
#
# Results: an XML file with 157,653 samples ([biosample_result_filtered.xml](data/samples/ncbi_samples/filtered/biosample_result_filtered.xml))
#
# To execute the sample selection step for the NCBI samples, unzip the file [2018-03-09-biosample_set.xml.zip](data/samples/ncbi_samples/original/2018-03-09-biosample_set.xml.zip) and run the following command:

# %%
# %run ./scripts/ncbi_biosample_1_filter.py
# Out:
# Input file: data/samples/ncbi_samples/original/2018-03-09-biosample_set.xml
# Processing NCBI samples...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ncbi_biosample_1_filter.py in <module>
#     135
#     136
# --> 137 if __name__ == "__main__": main()
#
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ncbi_biosample_1_filter.py in main()
#     108     print('Processing NCBI samples...')
#     109     # Read biosamples from XML file
# --> 110     content = pulldom.parse(INPUT_FILE)
#     111     processed_samples_count = 0
#     112     selected_samples_count = 0
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/xml/dom/pulldom.py in parse(stream_or_string, parser, bufsize)
#     326         bufsize = default_bufsize
#     327     if isinstance(stream_or_string, str):
# --> 328         stream = open(stream_or_string, 'rb')
#     329     else:
#     330         stream = stream_or_string
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/samples/ncbi_samples/original/2018-03-09-biosample_set.xml'

# %% [markdown]
# The original NCBI BioSamples file contains 7.8M samples and it is very large (20GB). If you want to test the selection step quickly, with a reduced number of samples, you can use the file [2018-03-09-biosample_set_fragment.xml](data/samples/ncbi_samples/original/2018-03-09-biosample_set_fragment.xml). This is a file that we generated for testing purposes and it contains only 29K NCBI samples. Note that if you want to run the sample selection step with this file, you will need to update [arm_constants.py](scripts/arm_constants.py) as follows:

# %%
NCBI_FILTER_INPUT_FILE = DATA_BASE_PATH + '/samples/ncbi_samples/original/2018-03-09-biosample_set_fragment.xml'

# %% [markdown]
# Then, you can run the selection step for the NCBI samples using:

# %%
# %run ./scripts/ncbi_biosample_1_filter.py
# Out:
# Input file: ./data/samples/ncbi_samples/original/2018-03-09-biosample_set.xml
# Processing NCBI samples...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ncbi_biosample_1_filter.py in <module>
#     135
#     136
# --> 137 if __name__ == "__main__": main()
#
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ncbi_biosample_1_filter.py in main()
#     108     print('Processing NCBI samples...')
#     109     # Read biosamples from XML file
# --> 110     content = pulldom.parse(INPUT_FILE)
#     111     processed_samples_count = 0
#     112     selected_samples_count = 0
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/xml/dom/pulldom.py in parse(stream_or_string, parser, bufsize)
#     326         bufsize = default_bufsize
#     327     if isinstance(stream_or_string, str):
# --> 328         stream = open(stream_or_string, 'rb')
#     329     else:
#     330         stream = stream_or_string
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/samples/ncbi_samples/original/2018-03-09-biosample_set.xml'

# %% [markdown]
# #### EBI BioSamples
#
# Script used: [ebi_biosamples_2_filter.py](scripts/ebi_biosamples_2_filter.py)

# %%
# %run ./scripts/ebi_biosamples_2_filter.py
# Out:
# Processing file: 00001 ebi_biosamples_1to10000.json
# Accumulated selected samples: 1029
# Processing file: 00002 ebi_biosamples_10001to20000.json
# Accumulated selected samples: 1897
# Processing file: 00003 ebi_biosamples_20001to30000.json
# Accumulated selected samples: 2555
# Processing file: 00004 ebi_biosamples_30001to40000.json
# Accumulated selected samples: 3434
# Processing file: 00005 ebi_biosamples_40001to50000.json
# Accumulated selected samples: 4372
# Processing file: 00006 ebi_biosamples_50001to60000.json
# Accumulated selected samples: 5147
# Processing file: 00007 ebi_biosamples_60001to70000.json
# Accumulated selected samples: 5611
# Processing file: 00008 ebi_biosamples_70001to80000.json
# Accumulated selected samples: 5810
# Processing file: 00009 ebi_biosamples_80001to90000.json
# Accumulated selected samples: 6336
# Processing file: 00010 ebi_biosamples_90001to100000.json
# Accumulated selected samples: 6567
# Processing file: 00011 ebi_biosamples_100001to110000.json
# Accumulated selected samples: 6746
# Processing file: 00012 ebi_biosamples_110001to120000.json
# Accumulated selected samples: 6972
# Processing file: 00013 ebi_biosamples_120001to130000.json
# Accumulated selected samples: 7037
# Processing file: 00014 ebi_biosamples_130001to140000.json
# Accumulated selected samples: 7553
# Processing file: 00015 ebi_biosamples_140001to150000.json
# Accumulated selected samples: 8002
# Processing file: 00016 ebi_biosamples_150001to160000.json
# Accumulated selected samples: 8384
# Processing file: 00017 ebi_biosamples_160001to170000.json
# Accumulated selected samples: 8913
# Processing file: 00018 ebi_biosamples_170001to180000.json
# Accumulated selected samples: 9512
# Processing file: 00019 ebi_biosamples_180001to190000.json
# Accumulated selected samples: 9870
# Processing file: 00020 ebi_biosamples_190001to200000.json
# Accumulated selected samples: 10307
# Processing file: 00021 ebi_biosamples_200001to210000.json
# Accumulated selected samples: 10762
# Processing file: 00022 ebi_biosamples_210001to220000.json
# Accumulated selected samples: 11127
# Processing file: 00023 ebi_biosamples_220001to230000.json
# Accumulated selected samples: 11502
# Processing file: 00024 ebi_biosamples_230001to240000.json
# Accumulated selected samples: 11902
# Processing file: 00025 ebi_biosamples_240001to250000.json
# Accumulated selected samples: 12173
# Processing file: 00026 ebi_biosamples_250001to260000.json
# Accumulated selected samples: 12641
# Processing file: 00027 ebi_biosamples_260001to270000.json
# Accumulated selected samples: 13319
# Processing file: 00028 ebi_biosamples_270001to280000.json
# Accumulated selected samples: 13857
# Processing file: 00029 ebi_biosamples_280001to290000.json
# Accumulated selected samples: 14539
# Processing file: 00030 ebi_biosamples_290001to300000.json
# Accumulated selected samples: 14791
# Processing file: 00031 ebi_biosamples_300001to310000.json
# Accumulated selected samples: 15198
# Processing file: 00032 ebi_biosamples_310001to320000.json
# Accumulated selected samples: 15342
# Processing file: 00033 ebi_biosamples_320001to330000.json
# Accumulated selected samples: 15775
# Processing file: 00034 ebi_biosamples_330001to340000.json
# Accumulated selected samples: 16290
# Processing file: 00035 ebi_biosamples_340001to350000.json
# Accumulated selected samples: 16570
# Processing file: 00036 ebi_biosamples_350001to360000.json
# Accumulated selected samples: 16953
# Processing file: 00037 ebi_biosamples_360001to370000.json
# Accumulated selected samples: 17476
# Processing file: 00038 ebi_biosamples_370001to380000.json
# Accumulated selected samples: 17978
# Processing file: 00039 ebi_biosamples_380001to390000.json
# Accumulated selected samples: 18482
# Processing file: 00040 ebi_biosamples_390001to400000.json
# Accumulated selected samples: 18923
# Processing file: 00041 ebi_biosamples_400001to410000.json
# Accumulated selected samples: 19119
# Processing file: 00042 ebi_biosamples_410001to420000.json
# Accumulated selected samples: 19260
# Processing file: 00043 ebi_biosamples_420001to430000.json
# Accumulated selected samples: 19466
# Processing file: 00044 ebi_biosamples_430001to440000.json
# Accumulated selected samples: 19805
# Processing file: 00045 ebi_biosamples_440001to450000.json
# Accumulated selected samples: 20265
# Processing file: 00046 ebi_biosamples_450001to460000.json
# Accumulated selected samples: 20723
# Processing file: 00047 ebi_biosamples_460001to470000.json
# Accumulated selected samples: 21048
# Processing file: 00048 ebi_biosamples_470001to480000.json
# Accumulated selected samples: 21320
# Processing file: 00049 ebi_biosamples_480001to490000.json
# Accumulated selected samples: 21768
# Processing file: 00050 ebi_biosamples_490001to500000.json
# Accumulated selected samples: 22463
# Processing file: 00051 ebi_biosamples_500001to510000.json
# Accumulated selected samples: 22699
# Processing file: 00052 ebi_biosamples_510001to520000.json
# Accumulated selected samples: 22877
# Processing file: 00053 ebi_biosamples_520001to530000.json
# Accumulated selected samples: 23161
# Processing file: 00054 ebi_biosamples_530001to540000.json
# Accumulated selected samples: 23393
# Processing file: 00055 ebi_biosamples_540001to550000.json
# Accumulated selected samples: 23697
# Processing file: 00056 ebi_biosamples_550001to560000.json
# Accumulated selected samples: 24669
# Processing file: 00057 ebi_biosamples_560001to570000.json
# Accumulated selected samples: 24914
# Processing file: 00058 ebi_biosamples_570001to580000.json
# Accumulated selected samples: 25185
# Processing file: 00059 ebi_biosamples_580001to590000.json
# Accumulated selected samples: 25475
# Processing file: 00060 ebi_biosamples_590001to600000.json
# Accumulated selected samples: 25668
# Processing file: 00061 ebi_biosamples_600001to610000.json
# Accumulated selected samples: 25698
# Processing file: 00062 ebi_biosamples_610001to620000.json
# Accumulated selected samples: 25777
# Processing file: 00063 ebi_biosamples_620001to630000.json
# Accumulated selected samples: 25843
# Processing file: 00064 ebi_biosamples_630001to640000.json
# Accumulated selected samples: 25902
# Processing file: 00065 ebi_biosamples_640001to650000.json
# Accumulated selected samples: 26122
# Processing file: 00066 ebi_biosamples_650001to660000.json
# Accumulated selected samples: 26652
# Processing file: 00067 ebi_biosamples_660001to670000.json
# Accumulated selected samples: 26753
# Processing file: 00068 ebi_biosamples_670001to680000.json
# Accumulated selected samples: 26808
# Processing file: 00069 ebi_biosamples_680001to690000.json
# Accumulated selected samples: 27218
# Processing file: 00070 ebi_biosamples_690001to700000.json
# Accumulated selected samples: 27718
# Processing file: 00071 ebi_biosamples_700001to710000.json
# Accumulated selected samples: 28001
# Processing file: 00072 ebi_biosamples_710001to720000.json
# Accumulated selected samples: 28119
# Processing file: 00073 ebi_biosamples_720001to730000.json
# Accumulated selected samples: 28379
# Processing file: 00074 ebi_biosamples_730001to740000.json
# Accumulated selected samples: 28635
# Processing file: 00075 ebi_biosamples_740001to750000.json
# Accumulated selected samples: 28878
# Processing file: 00076 ebi_biosamples_750001to760000.json
# Accumulated selected samples: 29452
# Processing file: 00077 ebi_biosamples_760001to770000.json
# Accumulated selected samples: 29957
# Processing file: 00078 ebi_biosamples_770001to780000.json
# Accumulated selected samples: 30368
# Processing file: 00079 ebi_biosamples_780001to790000.json
# Accumulated selected samples: 30832
# Processing file: 00080 ebi_biosamples_790001to800000.json
# Accumulated selected samples: 31150
# Processing file: 00081 ebi_biosamples_800001to810000.json
# Accumulated selected samples: 31510
# Processing file: 00082 ebi_biosamples_810001to820000.json
# Accumulated selected samples: 32010
# Processing file: 00083 ebi_biosamples_820001to830000.json
# Accumulated selected samples: 32603
# Processing file: 00084 ebi_biosamples_830001to840000.json
# Accumulated selected samples: 33133
# Processing file: 00085 ebi_biosamples_840001to850000.json
# Accumulated selected samples: 33658
# Processing file: 00086 ebi_biosamples_850001to860000.json
# Accumulated selected samples: 34171
# Processing file: 00087 ebi_biosamples_860001to870000.json
# Accumulated selected samples: 34735
# Processing file: 00088 ebi_biosamples_870001to880000.json
# Accumulated selected samples: 35036
# Processing file: 00089 ebi_biosamples_880001to890000.json
# Accumulated selected samples: 35962
# Processing file: 00090 ebi_biosamples_890001to900000.json
# Accumulated selected samples: 36352
# Processing file: 00091 ebi_biosamples_900001to910000.json
# Accumulated selected samples: 37337
# Processing file: 00092 ebi_biosamples_910001to920000.json
# Accumulated selected samples: 38050
# Processing file: 00093 ebi_biosamples_920001to930000.json
# Accumulated selected samples: 38838
# Processing file: 00094 ebi_biosamples_930001to940000.json
# Accumulated selected samples: 39093
# Processing file: 00095 ebi_biosamples_940001to950000.json
# Accumulated selected samples: 39559
# Processing file: 00096 ebi_biosamples_950001to960000.json
# Accumulated selected samples: 39951
# Processing file: 00097 ebi_biosamples_960001to970000.json
# Accumulated selected samples: 40819
# Processing file: 00098 ebi_biosamples_970001to980000.json
# Accumulated selected samples: 41075
# Processing file: 00099 ebi_biosamples_980001to990000.json
# Accumulated selected samples: 41307
# Processing file: 00100 ebi_biosamples_990001to1000000.json
# Accumulated selected samples: 41499
# Processing file: 00101 ebi_biosamples_1000001to1010000.json
# Accumulated selected samples: 41670
# Processing file: 00102 ebi_biosamples_1010001to1020000.json
# Accumulated selected samples: 42058
# Processing file: 00103 ebi_biosamples_1020001to1030000.json
# Accumulated selected samples: 42476
# Processing file: 00104 ebi_biosamples_1030001to1040000.json
# Accumulated selected samples: 42884
# Processing file: 00105 ebi_biosamples_1040001to1050000.json
# Accumulated selected samples: 43069
# Processing file: 00106 ebi_biosamples_1050001to1060000.json
# Accumulated selected samples: 43356
# Processing file: 00107 ebi_biosamples_1060001to1070000.json
# Accumulated selected samples: 43584
# Processing file: 00108 ebi_biosamples_1070001to1080000.json
# Accumulated selected samples: 44514
# Processing file: 00109 ebi_biosamples_1080001to1090000.json
# Accumulated selected samples: 45250
# Processing file: 00110 ebi_biosamples_1090001to1100000.json
# Accumulated selected samples: 45559
# Processing file: 00111 ebi_biosamples_1100001to1110000.json
# Accumulated selected samples: 45828
# Processing file: 00112 ebi_biosamples_1110001to1120000.json
# Accumulated selected samples: 45849
# Processing file: 00113 ebi_biosamples_1120001to1130000.json
# Accumulated selected samples: 46077
# Processing file: 00114 ebi_biosamples_1130001to1140000.json
# Accumulated selected samples: 46210
# Processing file: 00115 ebi_biosamples_1140001to1150000.json
# Accumulated selected samples: 46331
# Processing file: 00116 ebi_biosamples_1150001to1160000.json
# Accumulated selected samples: 46442
# Processing file: 00117 ebi_biosamples_1160001to1170000.json
# Accumulated selected samples: 46559
# Processing file: 00118 ebi_biosamples_1170001to1180000.json
# Accumulated selected samples: 46953
# Processing file: 00119 ebi_biosamples_1180001to1190000.json
# Accumulated selected samples: 47532
# Processing file: 00120 ebi_biosamples_1190001to1200000.json
# Accumulated selected samples: 47615
# Processing file: 00121 ebi_biosamples_1200001to1210000.json
# Accumulated selected samples: 47793
# Processing file: 00122 ebi_biosamples_1210001to1220000.json
# Accumulated selected samples: 47806
# Processing file: 00123 ebi_biosamples_1220001to1230000.json
# Accumulated selected samples: 47878
# Processing file: 00124 ebi_biosamples_1230001to1240000.json
# Accumulated selected samples: 48031
# Processing file: 00125 ebi_biosamples_1240001to1250000.json
# Accumulated selected samples: 48571
# Processing file: 00126 ebi_biosamples_1250001to1260000.json
# Accumulated selected samples: 49034
# Processing file: 00127 ebi_biosamples_1260001to1270000.json
# Accumulated selected samples: 49080
# Processing file: 00128 ebi_biosamples_1270001to1280000.json
# Accumulated selected samples: 49109
# Processing file: 00129 ebi_biosamples_1280001to1290000.json
# Accumulated selected samples: 49199
# Processing file: 00130 ebi_biosamples_1290001to1300000.json
# Accumulated selected samples: 49347
# Processing file: 00131 ebi_biosamples_1300001to1310000.json
# Accumulated selected samples: 49808
# Processing file: 00132 ebi_biosamples_1310001to1320000.json
# Accumulated selected samples: 50262
# Processing file: 00133 ebi_biosamples_1320001to1330000.json
# Accumulated selected samples: 50595
# Processing file: 00134 ebi_biosamples_1330001to1340000.json
# Accumulated selected samples: 51148
# Processing file: 00135 ebi_biosamples_1340001to1350000.json
# Accumulated selected samples: 51734
# Processing file: 00136 ebi_biosamples_1350001to1360000.json
# Accumulated selected samples: 52466
# Processing file: 00137 ebi_biosamples_1360001to1370000.json
# Accumulated selected samples: 53030
# Processing file: 00138 ebi_biosamples_1370001to1380000.json
# Accumulated selected samples: 53524
# Processing file: 00139 ebi_biosamples_1380001to1390000.json
# Accumulated selected samples: 53889
# Processing file: 00140 ebi_biosamples_1390001to1400000.json
# Accumulated selected samples: 54561
# Processing file: 00141 ebi_biosamples_1400001to1410000.json
# Accumulated selected samples: 54971
# Processing file: 00142 ebi_biosamples_1410001to1420000.json
# Accumulated selected samples: 55192
# Processing file: 00143 ebi_biosamples_1420001to1430000.json
# Accumulated selected samples: 55547
# Processing file: 00144 ebi_biosamples_1430001to1440000.json
# Accumulated selected samples: 55684
# Processing file: 00145 ebi_biosamples_1440001to1450000.json
# Accumulated selected samples: 56263
# Processing file: 00146 ebi_biosamples_1450001to1460000.json
# Accumulated selected samples: 56395
# Processing file: 00147 ebi_biosamples_1460001to1470000.json
# Accumulated selected samples: 56472
# Processing file: 00148 ebi_biosamples_1470001to1480000.json
# Accumulated selected samples: 56609
# Processing file: 00149 ebi_biosamples_1480001to1490000.json
# Accumulated selected samples: 57007
# Processing file: 00150 ebi_biosamples_1490001to1500000.json
# Accumulated selected samples: 57010
# Processing file: 00151 ebi_biosamples_1500001to1510000.json
# Accumulated selected samples: 57321
# Processing file: 00152 ebi_biosamples_1510001to1520000.json
# Accumulated selected samples: 57805
# Processing file: 00153 ebi_biosamples_1520001to1530000.json
# Accumulated selected samples: 58181
# Processing file: 00154 ebi_biosamples_1530001to1540000.json
# Accumulated selected samples: 58384
# Processing file: 00155 ebi_biosamples_1540001to1550000.json
# Accumulated selected samples: 58825
# Processing file: 00156 ebi_biosamples_1550001to1560000.json
# Accumulated selected samples: 58933
# Processing file: 00157 ebi_biosamples_1560001to1570000.json
# Accumulated selected samples: 59142
# Processing file: 00158 ebi_biosamples_1570001to1580000.json
# Accumulated selected samples: 59560
# Processing file: 00159 ebi_biosamples_1580001to1590000.json
# Accumulated selected samples: 59764
# Processing file: 00160 ebi_biosamples_1590001to1600000.json
# Accumulated selected samples: 59833
# Processing file: 00161 ebi_biosamples_1600001to1610000.json
# Accumulated selected samples: 60173
# Processing file: 00162 ebi_biosamples_1610001to1620000.json
# Accumulated selected samples: 60794
# Processing file: 00163 ebi_biosamples_1620001to1630000.json
# Accumulated selected samples: 60954
# Processing file: 00164 ebi_biosamples_1630001to1640000.json
# Accumulated selected samples: 61163
# Processing file: 00165 ebi_biosamples_1640001to1650000.json
# Accumulated selected samples: 61643
# Processing file: 00166 ebi_biosamples_1650001to1660000.json
# Accumulated selected samples: 62043
# Processing file: 00167 ebi_biosamples_1660001to1670000.json
# Accumulated selected samples: 62180
# Processing file: 00168 ebi_biosamples_1670001to1680000.json
# Accumulated selected samples: 62540
# Processing file: 00169 ebi_biosamples_1680001to1690000.json
# Accumulated selected samples: 63145
# Processing file: 00170 ebi_biosamples_1690001to1700000.json
# Accumulated selected samples: 63712
# Processing file: 00171 ebi_biosamples_1700001to1710000.json
# Accumulated selected samples: 63778
# Processing file: 00172 ebi_biosamples_1710001to1720000.json
# Accumulated selected samples: 64157
# Processing file: 00173 ebi_biosamples_1720001to1730000.json
# Accumulated selected samples: 64364
# Processing file: 00174 ebi_biosamples_1730001to1740000.json
# Accumulated selected samples: 64616
# Processing file: 00175 ebi_biosamples_1740001to1750000.json
# Accumulated selected samples: 65378
# Processing file: 00176 ebi_biosamples_1750001to1760000.json
# Accumulated selected samples: 65785
# Processing file: 00177 ebi_biosamples_1760001to1770000.json
# Accumulated selected samples: 66160
# Processing file: 00178 ebi_biosamples_1770001to1780000.json
# Accumulated selected samples: 66327
# Processing file: 00179 ebi_biosamples_1780001to1790000.json
# Accumulated selected samples: 66921
# Processing file: 00180 ebi_biosamples_1790001to1800000.json
# Accumulated selected samples: 67009
# Processing file: 00181 ebi_biosamples_1800001to1810000.json
# Accumulated selected samples: 67267
# Processing file: 00182 ebi_biosamples_1810001to1820000.json
# Accumulated selected samples: 67480
# Processing file: 00183 ebi_biosamples_1820001to1830000.json
# Accumulated selected samples: 67777
# Processing file: 00184 ebi_biosamples_1830001to1840000.json
# Accumulated selected samples: 68168
# Processing file: 00185 ebi_biosamples_1840001to1850000.json
# Accumulated selected samples: 68265
# Processing file: 00186 ebi_biosamples_1850001to1860000.json
# Accumulated selected samples: 68546
# Processing file: 00187 ebi_biosamples_1860001to1870000.json
# Accumulated selected samples: 68812
# Processing file: 00188 ebi_biosamples_1870001to1880000.json
# Accumulated selected samples: 69344
# Processing file: 00189 ebi_biosamples_1880001to1890000.json
# Accumulated selected samples: 69513
# Processing file: 00190 ebi_biosamples_1890001to1900000.json
# Accumulated selected samples: 69614
# Processing file: 00191 ebi_biosamples_1900001to1910000.json
# Accumulated selected samples: 70111
# Processing file: 00192 ebi_biosamples_1910001to1920000.json
# Accumulated selected samples: 70660
# Processing file: 00193 ebi_biosamples_1920001to1930000.json
# Accumulated selected samples: 70938
# Processing file: 00194 ebi_biosamples_1930001to1940000.json
# Accumulated selected samples: 71208
# Processing file: 00195 ebi_biosamples_1940001to1950000.json
# Accumulated selected samples: 71744
# Processing file: 00196 ebi_biosamples_1950001to1960000.json
# Accumulated selected samples: 72162
# Processing file: 00197 ebi_biosamples_1960001to1970000.json
# Accumulated selected samples: 72320
# Processing file: 00198 ebi_biosamples_1970001to1980000.json
# Accumulated selected samples: 72823
# Processing file: 00199 ebi_biosamples_1980001to1990000.json
# Accumulated selected samples: 72924
# Processing file: 00200 ebi_biosamples_1990001to2000000.json
# Accumulated selected samples: 72989
# Processing file: 00201 ebi_biosamples_2000001to2010000.json
# Accumulated selected samples: 73549
# Processing file: 00202 ebi_biosamples_2010001to2020000.json
# Accumulated selected samples: 74419
# Processing file: 00203 ebi_biosamples_2020001to2030000.json
# Accumulated selected samples: 75114
# Processing file: 00204 ebi_biosamples_2030001to2040000.json
# Accumulated selected samples: 75348
# Processing file: 00205 ebi_biosamples_2040001to2050000.json
# Accumulated selected samples: 75415
# Processing file: 00206 ebi_biosamples_2050001to2060000.json
# Accumulated selected samples: 75522
# Processing file: 00207 ebi_biosamples_2060001to2070000.json
# Accumulated selected samples: 75749
# Processing file: 00208 ebi_biosamples_2070001to2080000.json
# Accumulated selected samples: 76231
# Processing file: 00209 ebi_biosamples_2080001to2090000.json
# Accumulated selected samples: 76741
# Processing file: 00210 ebi_biosamples_2090001to2100000.json
# Accumulated selected samples: 77287
# Processing file: 00211 ebi_biosamples_2100001to2110000.json
# Accumulated selected samples: 77818
# Processing file: 00212 ebi_biosamples_2110001to2120000.json
# Accumulated selected samples: 78282
# Processing file: 00213 ebi_biosamples_2120001to2130000.json
# Accumulated selected samples: 78614
# Processing file: 00214 ebi_biosamples_2130001to2140000.json
# Accumulated selected samples: 79010
# Processing file: 00215 ebi_biosamples_2140001to2150000.json
# Accumulated selected samples: 79492
# Processing file: 00216 ebi_biosamples_2150001to2160000.json
# Accumulated selected samples: 79833
# Processing file: 00217 ebi_biosamples_2160001to2170000.json
# Accumulated selected samples: 79975
# Processing file: 00218 ebi_biosamples_2170001to2180000.json
# Accumulated selected samples: 79993
# Processing file: 00219 ebi_biosamples_2180001to2190000.json
# Accumulated selected samples: 80053
# Processing file: 00220 ebi_biosamples_2190001to2200000.json
# Accumulated selected samples: 80168
# Processing file: 00221 ebi_biosamples_2200001to2210000.json
# Accumulated selected samples: 80178
# Processing file: 00222 ebi_biosamples_2210001to2220000.json
# Accumulated selected samples: 80247
# Processing file: 00223 ebi_biosamples_2220001to2230000.json
# Accumulated selected samples: 80319
# Processing file: 00224 ebi_biosamples_2230001to2240000.json
# Accumulated selected samples: 80437
# Processing file: 00225 ebi_biosamples_2240001to2250000.json
# Accumulated selected samples: 80490
# Processing file: 00226 ebi_biosamples_2250001to2260000.json
# Accumulated selected samples: 80593
# Processing file: 00227 ebi_biosamples_2260001to2270000.json
# Accumulated selected samples: 80601
# Processing file: 00228 ebi_biosamples_2270001to2280000.json
# Accumulated selected samples: 80619
# Processing file: 00229 ebi_biosamples_2280001to2290000.json
# Accumulated selected samples: 81030
# Processing file: 00230 ebi_biosamples_2290001to2300000.json
# Accumulated selected samples: 81344
# Processing file: 00231 ebi_biosamples_2300001to2310000.json
# Accumulated selected samples: 81424
# Processing file: 00232 ebi_biosamples_2310001to2320000.json
# Accumulated selected samples: 81509
# Processing file: 00233 ebi_biosamples_2320001to2330000.json
# Accumulated selected samples: 81703
# Processing file: 00234 ebi_biosamples_2330001to2340000.json
# Accumulated selected samples: 81829
# Processing file: 00235 ebi_biosamples_2340001to2350000.json
# Accumulated selected samples: 82227
# Processing file: 00236 ebi_biosamples_2350001to2360000.json
# Accumulated selected samples: 83374
# Processing file: 00237 ebi_biosamples_2360001to2370000.json
# Accumulated selected samples: 84718
# Processing file: 00238 ebi_biosamples_2370001to2380000.json
# Accumulated selected samples: 85546
# Processing file: 00239 ebi_biosamples_2380001to2390000.json
# Accumulated selected samples: 86173
# Processing file: 00240 ebi_biosamples_2390001to2400000.json
# Accumulated selected samples: 86595
# Processing file: 00241 ebi_biosamples_2400001to2410000.json
# Accumulated selected samples: 87104
# Processing file: 00242 ebi_biosamples_2410001to2420000.json
# Accumulated selected samples: 87851
# Processing file: 00243 ebi_biosamples_2420001to2430000.json
# Accumulated selected samples: 88322
# Processing file: 00244 ebi_biosamples_2430001to2440000.json
# Accumulated selected samples: 89168
# Processing file: 00245 ebi_biosamples_2440001to2450000.json
# Accumulated selected samples: 89304
# Processing file: 00246 ebi_biosamples_2450001to2460000.json
# Accumulated selected samples: 89701
# Processing file: 00247 ebi_biosamples_2460001to2470000.json
# Accumulated selected samples: 89955
# Processing file: 00248 ebi_biosamples_2470001to2480000.json
# Accumulated selected samples: 90138
# Processing file: 00249 ebi_biosamples_2480001to2490000.json
# Accumulated selected samples: 90417
# Processing file: 00250 ebi_biosamples_2490001to2500000.json
# Accumulated selected samples: 91155
# Processing file: 00251 ebi_biosamples_2500001to2510000.json
# Accumulated selected samples: 91436
# Processing file: 00252 ebi_biosamples_2510001to2520000.json
# Accumulated selected samples: 91593
# Processing file: 00253 ebi_biosamples_2520001to2530000.json
# Accumulated selected samples: 91722
# Processing file: 00254 ebi_biosamples_2530001to2540000.json
# Accumulated selected samples: 91784
# Processing file: 00255 ebi_biosamples_2540001to2550000.json
# Accumulated selected samples: 91827
# Processing file: 00256 ebi_biosamples_2550001to2560000.json
# Accumulated selected samples: 91833
# Processing file: 00257 ebi_biosamples_2560001to2570000.json
# Accumulated selected samples: 91837
# Processing file: 00258 ebi_biosamples_2570001to2580000.json
# Accumulated selected samples: 91837
# Processing file: 00259 ebi_biosamples_2580001to2590000.json
# Accumulated selected samples: 91862
# Processing file: 00260 ebi_biosamples_2590001to2600000.json
# Accumulated selected samples: 93028
# Processing file: 00261 ebi_biosamples_2600001to2610000.json
# Accumulated selected samples: 93506
# Processing file: 00262 ebi_biosamples_2610001to2620000.json
# Accumulated selected samples: 94316
# Processing file: 00263 ebi_biosamples_2620001to2630000.json
# Accumulated selected samples: 95104
# Processing file: 00264 ebi_biosamples_2630001to2640000.json
# Accumulated selected samples: 95544
# Processing file: 00265 ebi_biosamples_2640001to2650000.json
# Accumulated selected samples: 95799
# Processing file: 00266 ebi_biosamples_2650001to2660000.json
# Accumulated selected samples: 97071
# Processing file: 00267 ebi_biosamples_2660001to2670000.json
# Accumulated selected samples: 98082
# Processing file: 00268 ebi_biosamples_2670001to2680000.json
# Accumulated selected samples: 98577
# Processing file: 00269 ebi_biosamples_2680001to2690000.json
# Accumulated selected samples: 99313
# Processing file: 00270 ebi_biosamples_2690001to2700000.json
# Accumulated selected samples: 99317
# Processing file: 00271 ebi_biosamples_2700001to2710000.json
# Accumulated selected samples: 99619
# Processing file: 00272 ebi_biosamples_2710001to2720000.json
# Accumulated selected samples: 99647
# Processing file: 00273 ebi_biosamples_2720001to2730000.json
# Accumulated selected samples: 100169
# Processing file: 00274 ebi_biosamples_2730001to2740000.json
# Accumulated selected samples: 100680
# Processing file: 00275 ebi_biosamples_2740001to2750000.json
# Accumulated selected samples: 101395
# Processing file: 00276 ebi_biosamples_2750001to2760000.json
# Accumulated selected samples: 102069
# Processing file: 00277 ebi_biosamples_2760001to2770000.json
# Accumulated selected samples: 102655
# Processing file: 00278 ebi_biosamples_2770001to2780000.json
# Accumulated selected samples: 103157
# Processing file: 00279 ebi_biosamples_2780001to2790000.json
# Accumulated selected samples: 103311
# Processing file: 00280 ebi_biosamples_2790001to2800000.json
# Accumulated selected samples: 103421
# Processing file: 00281 ebi_biosamples_2800001to2810000.json
# Accumulated selected samples: 103881
# Processing file: 00282 ebi_biosamples_2810001to2820000.json
# Accumulated selected samples: 103894
# Processing file: 00283 ebi_biosamples_2820001to2830000.json
# Accumulated selected samples: 103952
# Processing file: 00284 ebi_biosamples_2830001to2840000.json
# Accumulated selected samples: 104164
# Processing file: 00285 ebi_biosamples_2840001to2850000.json
# Accumulated selected samples: 104811
# Processing file: 00286 ebi_biosamples_2850001to2860000.json
# Accumulated selected samples: 104898
# Processing file: 00287 ebi_biosamples_2860001to2870000.json
# Accumulated selected samples: 105081
# Processing file: 00288 ebi_biosamples_2870001to2880000.json
# Accumulated selected samples: 105284
# Processing file: 00289 ebi_biosamples_2880001to2890000.json
# Accumulated selected samples: 105412
# Processing file: 00290 ebi_biosamples_2890001to2900000.json
# Accumulated selected samples: 105528
# Processing file: 00291 ebi_biosamples_2900001to2910000.json
# Accumulated selected samples: 105816
# Processing file: 00292 ebi_biosamples_2910001to2920000.json
# Accumulated selected samples: 106118
# Processing file: 00293 ebi_biosamples_2920001to2930000.json
# Accumulated selected samples: 106443
# Processing file: 00294 ebi_biosamples_2930001to2940000.json
# Accumulated selected samples: 106666
# Processing file: 00295 ebi_biosamples_2940001to2950000.json
# Accumulated selected samples: 106745
# Processing file: 00296 ebi_biosamples_2950001to2960000.json
# Accumulated selected samples: 107009
# Processing file: 00297 ebi_biosamples_2960001to2970000.json
# Accumulated selected samples: 107151
# Processing file: 00298 ebi_biosamples_2970001to2980000.json
# Accumulated selected samples: 107275
# Processing file: 00299 ebi_biosamples_2980001to2990000.json
# Accumulated selected samples: 107350
# Processing file: 00300 ebi_biosamples_2990001to3000000.json
# Accumulated selected samples: 107646
# Processing file: 00301 ebi_biosamples_3000001to3010000.json
# Accumulated selected samples: 107966
# Processing file: 00302 ebi_biosamples_3010001to3020000.json
# Accumulated selected samples: 108374
# Processing file: 00303 ebi_biosamples_3020001to3030000.json
# Accumulated selected samples: 108813
# Processing file: 00304 ebi_biosamples_3030001to3040000.json
# Accumulated selected samples: 108930
# Processing file: 00305 ebi_biosamples_3040001to3050000.json
# Accumulated selected samples: 109054
# Processing file: 00306 ebi_biosamples_3050001to3060000.json
# Accumulated selected samples: 109258
# Processing file: 00307 ebi_biosamples_3060001to3070000.json
# Accumulated selected samples: 109291
# Processing file: 00308 ebi_biosamples_3070001to3080000.json
# Accumulated selected samples: 109437
# Processing file: 00309 ebi_biosamples_3080001to3090000.json
# Accumulated selected samples: 109490
# Processing file: 00310 ebi_biosamples_3090001to3100000.json
# Accumulated selected samples: 109575
# Processing file: 00311 ebi_biosamples_3100001to3110000.json
# Accumulated selected samples: 109688
# Processing file: 00312 ebi_biosamples_3110001to3120000.json
# Accumulated selected samples: 109795
# Processing file: 00313 ebi_biosamples_3120001to3130000.json
# Accumulated selected samples: 109940
# Processing file: 00314 ebi_biosamples_3130001to3140000.json
# Accumulated selected samples: 110047
# Processing file: 00315 ebi_biosamples_3140001to3150000.json
# Accumulated selected samples: 110878
# Processing file: 00316 ebi_biosamples_3150001to3160000.json
# Accumulated selected samples: 111883
# Processing file: 00317 ebi_biosamples_3160001to3170000.json
# Accumulated selected samples: 112651
# Processing file: 00318 ebi_biosamples_3170001to3180000.json
# Accumulated selected samples: 113149
# Processing file: 00319 ebi_biosamples_3180001to3190000.json
# Accumulated selected samples: 113404
# Processing file: 00320 ebi_biosamples_3190001to3200000.json
# Accumulated selected samples: 113664
# Processing file: 00321 ebi_biosamples_3200001to3210000.json
# Accumulated selected samples: 113750
# Processing file: 00322 ebi_biosamples_3210001to3220000.json
# Accumulated selected samples: 114037
# Processing file: 00323 ebi_biosamples_3220001to3230000.json
# Accumulated selected samples: 114227
# Processing file: 00324 ebi_biosamples_3230001to3240000.json
# Accumulated selected samples: 114445
# Processing file: 00325 ebi_biosamples_3240001to3250000.json
# Accumulated selected samples: 114691
# Processing file: 00326 ebi_biosamples_3250001to3260000.json
# Accumulated selected samples: 114946
# Processing file: 00327 ebi_biosamples_3260001to3270000.json
# Accumulated selected samples: 115150
# Processing file: 00328 ebi_biosamples_3270001to3280000.json
# Accumulated selected samples: 115345
# Processing file: 00329 ebi_biosamples_3280001to3290000.json
# Accumulated selected samples: 115464
# Processing file: 00330 ebi_biosamples_3290001to3300000.json
# Accumulated selected samples: 115500
# Processing file: 00331 ebi_biosamples_3300001to3310000.json
# Accumulated selected samples: 115578
# Processing file: 00332 ebi_biosamples_3310001to3320000.json
# Accumulated selected samples: 115681
# Processing file: 00333 ebi_biosamples_3320001to3330000.json
# Accumulated selected samples: 115903
# Processing file: 00334 ebi_biosamples_3330001to3340000.json
# Accumulated selected samples: 116197
# Processing file: 00335 ebi_biosamples_3340001to3350000.json
# Accumulated selected samples: 116345
# Processing file: 00336 ebi_biosamples_3350001to3360000.json
# Accumulated selected samples: 116588
# Processing file: 00337 ebi_biosamples_3360001to3370000.json
# Accumulated selected samples: 116691
# Processing file: 00338 ebi_biosamples_3370001to3380000.json
# Accumulated selected samples: 116762
# Processing file: 00339 ebi_biosamples_3380001to3390000.json
# Accumulated selected samples: 116874
# Processing file: 00340 ebi_biosamples_3390001to3400000.json
# Accumulated selected samples: 116987
# Processing file: 00341 ebi_biosamples_3400001to3410000.json
# Accumulated selected samples: 117526
# Processing file: 00342 ebi_biosamples_3410001to3420000.json
# Accumulated selected samples: 118301
# Processing file: 00343 ebi_biosamples_3420001to3430000.json
# Accumulated selected samples: 118809
# Processing file: 00344 ebi_biosamples_3430001to3440000.json
# Accumulated selected samples: 119251
# Processing file: 00345 ebi_biosamples_3440001to3450000.json
# Accumulated selected samples: 119420
# Processing file: 00346 ebi_biosamples_3450001to3460000.json
# Accumulated selected samples: 119520
# Processing file: 00347 ebi_biosamples_3460001to3470000.json
# Accumulated selected samples: 119639
# Processing file: 00348 ebi_biosamples_3470001to3480000.json
# Accumulated selected samples: 120262
# Processing file: 00349 ebi_biosamples_3480001to3490000.json
# Accumulated selected samples: 121149
# Processing file: 00350 ebi_biosamples_3490001to3500000.json
# Accumulated selected samples: 121468
# Processing file: 00351 ebi_biosamples_3500001to3510000.json
# Accumulated selected samples: 121525
# Processing file: 00352 ebi_biosamples_3510001to3520000.json
# Accumulated selected samples: 121667
# Processing file: 00353 ebi_biosamples_3520001to3530000.json
# Accumulated selected samples: 121825
# Processing file: 00354 ebi_biosamples_3530001to3540000.json
# Accumulated selected samples: 121887
# Processing file: 00355 ebi_biosamples_3540001to3550000.json
# Accumulated selected samples: 122084
# Processing file: 00356 ebi_biosamples_3550001to3560000.json
# Accumulated selected samples: 122504
# Processing file: 00357 ebi_biosamples_3560001to3570000.json
# Accumulated selected samples: 122822
# Processing file: 00358 ebi_biosamples_3570001to3580000.json
# Accumulated selected samples: 123101
# Processing file: 00359 ebi_biosamples_3580001to3590000.json
# Accumulated selected samples: 123180
# Processing file: 00360 ebi_biosamples_3590001to3600000.json
# Accumulated selected samples: 123294
# Processing file: 00361 ebi_biosamples_3600001to3610000.json
# Accumulated selected samples: 123504
# Processing file: 00362 ebi_biosamples_3610001to3620000.json
# Accumulated selected samples: 123665
# Processing file: 00363 ebi_biosamples_3620001to3630000.json
# Accumulated selected samples: 123805
# Processing file: 00364 ebi_biosamples_3630001to3640000.json
# Accumulated selected samples: 124025
# Processing file: 00365 ebi_biosamples_3640001to3650000.json
# Accumulated selected samples: 124217
# Processing file: 00366 ebi_biosamples_3650001to3660000.json
# Accumulated selected samples: 124480
# Processing file: 00367 ebi_biosamples_3660001to3670000.json
# Accumulated selected samples: 124812
# Processing file: 00368 ebi_biosamples_3670001to3680000.json
# Accumulated selected samples: 125070
# Processing file: 00369 ebi_biosamples_3680001to3690000.json
# Accumulated selected samples: 125434
# Processing file: 00370 ebi_biosamples_3690001to3700000.json
# Accumulated selected samples: 125507
# Processing file: 00371 ebi_biosamples_3700001to3710000.json
# Accumulated selected samples: 125559
# Processing file: 00372 ebi_biosamples_3710001to3720000.json
# Accumulated selected samples: 125600
# Processing file: 00373 ebi_biosamples_3720001to3730000.json
# Accumulated selected samples: 125956
# Processing file: 00374 ebi_biosamples_3730001to3740000.json
# Accumulated selected samples: 126048
# Processing file: 00375 ebi_biosamples_3740001to3750000.json
# Accumulated selected samples: 126317
# Processing file: 00376 ebi_biosamples_3750001to3760000.json
# Accumulated selected samples: 126786
# Processing file: 00377 ebi_biosamples_3760001to3770000.json
# Accumulated selected samples: 126863
# Processing file: 00378 ebi_biosamples_3770001to3780000.json
# Accumulated selected samples: 126985
# Processing file: 00379 ebi_biosamples_3780001to3790000.json
# Accumulated selected samples: 127067
# Processing file: 00380 ebi_biosamples_3790001to3800000.json
# Accumulated selected samples: 127441
# Processing file: 00381 ebi_biosamples_3800001to3810000.json
# Accumulated selected samples: 127512
# Processing file: 00382 ebi_biosamples_3810001to3820000.json
# Accumulated selected samples: 127676
# Processing file: 00383 ebi_biosamples_3820001to3830000.json
# Accumulated selected samples: 128200
# Processing file: 00384 ebi_biosamples_3830001to3840000.json
# Accumulated selected samples: 128396
# Processing file: 00385 ebi_biosamples_3840001to3850000.json
# Accumulated selected samples: 128799
# Processing file: 00386 ebi_biosamples_3850001to3860000.json
# Accumulated selected samples: 128853
# Processing file: 00387 ebi_biosamples_3860001to3870000.json
# Accumulated selected samples: 128952
# Processing file: 00388 ebi_biosamples_3870001to3880000.json
# Accumulated selected samples: 130607
# Processing file: 00389 ebi_biosamples_3880001to3890000.json
# Accumulated selected samples: 130800
# Processing file: 00390 ebi_biosamples_3890001to3900000.json
# Accumulated selected samples: 130938
# Processing file: 00391 ebi_biosamples_3900001to3910000.json
# Accumulated selected samples: 130961
# Processing file: 00392 ebi_biosamples_3910001to3920000.json
# Accumulated selected samples: 131009
# Processing file: 00393 ebi_biosamples_3920001to3930000.json
# Accumulated selected samples: 131087
# Processing file: 00394 ebi_biosamples_3930001to3940000.json
# Accumulated selected samples: 131241
# Processing file: 00395 ebi_biosamples_3940001to3950000.json
# Accumulated selected samples: 131586
# Processing file: 00396 ebi_biosamples_3950001to3960000.json
# Accumulated selected samples: 131618
# Processing file: 00397 ebi_biosamples_3960001to3970000.json
# Accumulated selected samples: 131653
# Processing file: 00398 ebi_biosamples_3970001to3980000.json
# Accumulated selected samples: 131664
# Processing file: 00399 ebi_biosamples_3980001to3990000.json
# Accumulated selected samples: 131734
# Processing file: 00400 ebi_biosamples_3990001to4000000.json
# Accumulated selected samples: 132396
# Processing file: 00401 ebi_biosamples_4000001to4010000.json
# Accumulated selected samples: 133181
# Processing file: 00402 ebi_biosamples_4010001to4020000.json
# Accumulated selected samples: 133359
# Processing file: 00403 ebi_biosamples_4020001to4030000.json
# Accumulated selected samples: 133421
# Processing file: 00404 ebi_biosamples_4030001to4040000.json
# Accumulated selected samples: 133541
# Processing file: 00405 ebi_biosamples_4040001to4050000.json
# Accumulated selected samples: 133605
# Processing file: 00406 ebi_biosamples_4050001to4060000.json
# Accumulated selected samples: 133681
# Processing file: 00407 ebi_biosamples_4060001to4070000.json
# Accumulated selected samples: 134339
# Processing file: 00408 ebi_biosamples_4070001to4080000.json
# Accumulated selected samples: 134381
# Processing file: 00409 ebi_biosamples_4080001to4090000.json
# Accumulated selected samples: 134565
# Processing file: 00410 ebi_biosamples_4090001to4100000.json
# Accumulated selected samples: 134669
# Processing file: 00411 ebi_biosamples_4100001to4110000.json
# Accumulated selected samples: 134732
# Processing file: 00412 ebi_biosamples_4110001to4120000.json
# Accumulated selected samples: 135187
# Finished filtering:
# - Initial samples: 4120000
# - Removed by filter_is_homo_sapiens: 2738157(66%)
# - Removed by filter_is_geo_sample: 0(0%)
# - Removed by filter_not_geo_sample: 0(0%)
# - Removed by filter_is_arrayexpress_sample: 0(0%)
# - Removed by filter_not_arrayexpress_sample: 0(0%)
# - Removed by filter_not_ncbi_sample: 0(0%)
# - Removed by filter_not_ena_sample: 0(0%)
# - Removed by filter_has_minimum_relevant_attributes_count: 1246656(30%)
# - Filtered samples: 135187
# Exporting selected samples

# %% [markdown]
# Results: 14 JSON files with a total of 135,187 samples, available in [this folder](data/samples/ebi_samples/filtered/)

# %% [markdown]
# ### 2.3. Generate CEDAR instances
#
# We transformed the NCBI and EBI samples obtained from the previous step to CEDAR template instances conforming to [CEDAR's JSON-based Template Model](https://metadatacenter.org/tools-training/outreach/cedar-template-model).
#
# [ebi_biosamples_3_to_cedar_instances.py](scripts/ebi_biosamples_3_to_cedar_instances.py)

# %%
# %run ./scripts/ebi_biosamples_3_to_cedar_instances.py
# Out:
# Reading EBI biosamples from folder: ./tmp/samples/ebi_samples/filtered
# Total no. samples: 135187
# Generating CEDAR instances...
# No. instances generated: 5000(4%)
# No. instances generated: 10000(7%)
# No. instances generated: 15000(11%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ebi_biosamples_3_to_cedar_instances.py in <module>
#     204
#     205
# --> 206 if __name__ == "__main__": main()
#     207
#     208
#
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ebi_biosamples_3_to_cedar_instances.py in main()
#     169             break
#     170
# --> 171         instance = ebi_biosample_to_cedar_instance(biosample)
#     172
#     173         # Generate output path
#
# ~/Development/git_repos/CEDAR/cedar-experiments/value-recommender-evaluation/scripts/ebi_biosamples_3_to_cedar_instances.py in ebi_biosample_to_cedar_instance(ebi_biosample)
#     130     """
#     131     json_file = open(EMPTY_BIOSAMPLE_INSTANCE_PATH, "r")  # Open the JSON file for writing
# --> 132     instance = json.load(json_file)  # Read the JSON into the buffer
#     133     json_file.close()  # Close the JSON file
#     134
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %% [markdown]
# [ncbi_biosample_2_to_cedar_instances.py](scripts/ncbi_biosamples_2_to_cedar_instances.py)

# %%
from shutil import copyfile
import scripts.arm_constants as constants

# Copy the pre-generated file with all the filtered NCBI samples to right folder
src = constants.DATA_BASE_PATH + '/samples/ncbi_samples/filtered/biosample_result_filtered.xml'
dst = constants.NCBI_FILTER_OUTPUT_FILE
copyfile(src, dst)

# %run ./scripts/ncbi_biosample_2_to_cedar_instances.py
# Out:
# Reading file: ./tmp/samples/ncbi_samples/filtered/biosample_result_filtered.xml
# Extracting all samples from file (no. samples: 157653)

# %% [markdown]
# Output: NCBI testing test with samples that are not in the NCBI training set nor the EBI training set.
#
# ## 5. Generate annotated instances and mappings file
#
# ### 5.1. Extraction of unique values from CEDAR instances
#
# Script: `cedar_annotator/1_unique_values_extractor.py`
#
# (`cedar_annotator/annotation_constants.py`)
# ```
# VALUES_EXTRACTION_INSTANCE_PATHS = [NCBI_INSTANCES_OUTPUT_BASE_PATH + '/training', NCBI_INSTANCES_OUTPUT_BASE_PATH + '/testing',
#                   EBI_INSTANCES_OUTPUT_BASE_PATH + '/training', EBI_INSTANCES_OUTPUT_BASE_PATH + '/testing']
# VALUES_EXTRACTION_OUTPUT_FILE_PATH = BASE_PATH + 'cedar_instances_annotated/unique_values/unique_values.txt'
# ```
#
# No. files processed: 240,000
# No. unique values identified: 26,166 (26,122 valid values)
#
# ### 5.2. Annotation of unique values
#
# Script: `cedar_annotator/1_unique_values_annotator.py`
#
# (`cedar_annotator/annotation_constants.py`)
# ```
# VALUES_ANNOTATION_INPUT_VALUES_FILE_PATH = VALUES_EXTRACTION_OUTPUT_FILE_PATH
# VALUES_ANNOTATION_OUTPUT_FILE_PATH = BASE_PATH + '/cedar_instances_annotated/unique_values/unique_values_annotated.json'
# VALUES_ANNOTATION_MAPPINGS_FILE_PATH = '/cedar_instances_annotated/unique_values/mappings.json'
# VALUES_ANNOTATION_BIOPORTAL_API_KEY = '<my_BP_API_key>'
# VALUES_ANNOTATION_VALUES_PER_ITERATION = 2000
# VALUES_ANNOTATION_PREFERRED_ONTOLOGIES = ['EFO', 'DOID', 'OBI', 'CL', 'CLO', 'PATO', 'CHEBI', 'BFO', 'PR', 'CPT',
#                                           'MEDDRA', 'UBERON','RXNORM', 'SNOMEDCT', 'FMA', 'LOINC', 'NDFRT', 'EDAM',
#                                           'RCD', 'ICD10CM', 'SNMI', 'BTO', 'MESH', 'NCIT', 'OMIM']
# VALUES_ANNOTATION_USE_NORMALIZED_VALUES = False
# VALUES_ANNOTATION_NORMALIZED_VALUES_FILE_NAME = 'normalized_values.json'  # We assume that the file is stored in the current path
# VALUES_ANNOTATION_LIMIT_TO_PREFERRED_ONTOLOGIES = False
# ```
#
# No. resulting URIs: 12,711
# No. values that were no annotated: 26,166 - 12,711
#
# ### 5.3. Annotation of CEDAR instances
# This process uses the output of the previous steps to annotate all instances without making any calls to BioPortal.
#
# Script: `cedar_annotator/3_cedar_instances_annotator.py`
#
# (`cedar_annotator/annotation_constants.py`)
# ```
# INSTANCES_ANNOTATION_INPUT_BASE_PATH = BASE_PATH + '/cedar_instances'
# INSTANCES_ANNOTATION_OUTPUT_BASE_PATH = BASE_PATH + '/cedar_instances_annotated'
# INSTANCES_ANNOTATION_INPUT_FOLDERS = [
#     INSTANCES_ANNOTATION_INPUT_BASE_PATH + '/ncbi_cedar_instances/training',
#     INSTANCES_ANNOTATION_INPUT_BASE_PATH + '/ncbi_cedar_instances/testing',
#     INSTANCES_ANNOTATION_INPUT_BASE_PATH + '/ebi_cedar_instances/training',
#     INSTANCES_ANNOTATION_INPUT_BASE_PATH + '/ebi_cedar_instances/testing'
# ]
# INSTANCES_ANNOTATION_OUTPUT_SUFFIX = '_annotated'
# INSTANCES_ANNOTATION_VALUES_ANNOTATED_FILE_PATH = VALUES_ANNOTATION_OUTPUT_FILE_PATH
# INSTANCES_ANNOTATION_NCBI_EMPTY_INSTANCE_ANNOTATED_PATH = BASE_PATH + '/cedar_templates_and_reference_instances/ncbi/ncbi_biosample_instance_annotated_empty.json'
# INSTANCES_ANNOTATION_EBI_EMPTY_INSTANCE_ANNOTATED_PATH = BASE_PATH + '/cedar_templates_and_reference_instances/ebi/ebi_biosample_instance_annotated_empty.json'
# INSTANCES_ANNOTATION_NON_ANNOTATED_VALUES_FILE_NAME = 'non_annotated_values_report.txt'
# INSTANCES_ANNOTATION_USE_NORMALIZED_VALUES = False
# INSTANCES_ANNOTATION_NORMALIZED_VALUES_FILE_NAME = 'normalized_values.json'
# ```
#
# NCBI training:
# No. total values: 336,351
# No. non annotated values: 47,877 (14%)
#
# NCBI testing:
# No. total values: 58,529 (394880-336351)
# No. non annotated values: 8,877 (56754-47877) (14%)
#
# EBI training:
# No. total values: 328,904(723784-394880)
# No. non annotated values: 46,166 (102920-56754) (14%)
#
# EBI testing:
# No. total values: 57,865 (781649-723784)
# No. non annotated values: 8,060 (110980-102920) (14%)
#
# ## 6. Generate Association Rules
#
# Delete the current cedar-value-recommender index from Elasticsearch: `DELETE cedar-value-recommender`
#
# Restart the cedar-value-recommender-server. The index will be created again, with the corresponding ES mappings.
#
# Update the following file:
# "/Users/marcosmr/Development/git_repos/CEDAR/cedar-valuerecommender-server/cedar-valuerecommender-server-core/src/main/java/org/metadatacenter/intelligentauthoring/valuerecommender/util/Constants.java"
#
# READ_INSTANCES_FROM_CEDAR = false
# Update the variable "CEDAR_INSTANCES_PATH" with the full paths of the corresponding instances.
#
# Apriori configuration:
# ```
# public static final int APRIORI_MAX_NUM_RULES = 1000000;
# public static int MIN_SUPPORTING_INSTANCES = 5; // The support will be dynamically calculated based on this value
# public static final double MIN_CONFIDENCE = 0.3;
# public static final double MIN_LIFT = 1.2;
# public static final double MIN_LEVERAGE = 1.1;
# public static final double MIN_CONVICTION = 1.1;
# public static final int METRIC_TYPE_ID = 0; // 0 = Confidence | 1 = Lift | 2 = Leverage | 3 = Conviction
# public static final String SUPPORT_METRIC_NAME = "Support";
# public static final String CONFIDENCE_METRIC_NAME = "Confidence";
# public static final String LIFT_METRIC_NAME = "Lift";
# public static final String LEVERAGE_METRIC_NAME = "Leverage";
# public static final String CONVICTION_METRIC_NAME = "Conviction";
# public static final boolean VERBOSE_MODE = true;
# ```
#
# For NCBI, POST to https://valuerecommender.metadatacenter.orgx/generate-rules:
# {
# 	"templateIds" : [
# 		"https://repo.metadatacenter.orgx/templates/eef6f399-aa4e-4982-ab04-ad8e9635aa91"]
# }
#
# For EBI:
# {
# 	"templateIds" : [
# 		"https://repo.metadatacenter.orgx/templates/6b6c76e6-1d9b-4096-9702-133e25ecd140"]
# }
#
# ### 6.1. Generate rules for the NCBI training set (free text)
# CEDAR_INSTANCES_PATH = "/Users/marcosmr/tmp/ARM_resources/EVALUATION/cedar_instances/ncbi_cedar_instances/training"
#
# Create a backup of the generated rules in ES:
# ```json
# POST _reindex
# {
#   "source": {
#     "index": "cedar-value-recommender"
#   },
#   "dest": {
#     "index": "cedar-value-recommender_backup-ncbi"
#   }
# }
# ```
#
# Number of rules generated: 52,192
# No. rules after filtering: 30,295
# Execution time: 5,682
#
# ### 6.2. Generate rules for the EBI training set (free text)
# CEDAR_INSTANCES_PATH = "/Users/marcosmr/tmp/ARM_resources/EVALUATION/cedar_instances/ebi_cedar_instances/training"
#
# Create a backup of the generated rules in ES:
# ```json
# POST _reindex
# {
#   "source": {
#     "index": "cedar-value-recommender"
#   },
#   "dest": {
#     "index": "cedar-value-recommender_backup-ncbi-annotated"
#   }
# }
# ```
# Number of rules generated: 36915
# No. rules after filtering: 24983
# Execution time: 4079 seg.
#
# ### 6.3. Generate rules for the NCBI training set (annotated)
#
# Don't forget to put the mappings.json file into the appropriate resources folder in the value recommender server so that the rules can be created using those mappings.
# value-recommender-server
#
# CEDAR_INSTANCES_PATH = "/Users/marcosmr/tmp/ARM_resources/EVALUATION/cedar_instances_annotated/ncbi_cedar_instances/training"
#
# Create a backup of the generated rules in ES:
# ```json
# POST _reindex
# {
#   "source": {
#     "index": "cedar-value-recommender"
#   },
#   "dest": {
#     "index": "cedar-value-recommender_backup-ebi"
#   }
# }
# ```
#
# Number of rules generated: 18223
# No. rules after filtering: 12400
# Execution time: 1,293 seg.
#
#
# ### 6.4. Generate rules for the EBI training set (annotated)
# CEDAR_INSTANCES_PATH = "/Users/marcosmr/tmp/ARM_resources/EVALUATION/cedar_instances_annotated/ebi_cedar_instances/training"
#
# Create a backup of the generated rules in ES:
# ```json
# POST _reindex
# {
#   "source": {
#     "index": "cedar-value-recommender"
#   },
#   "dest": {
#     "index": "cedar-value-recommender_backup-ebi-annotated"
#   }
# }
# ```
#
# Number of rules generated: 16838
# No. rules after filtering: 11932
# Execution time: 1087 seg.
#
# The ARFF files generated will be stored in a local temporal folder. The specific path is logged. In my case, for the NCBI template the path to the ARFF file is: `/var/folders/kk/7t15qjtd5cq0kpqnvm2mxp_00000gn/T//cedar-valuerecommender-server/arff-files/eef6f399-aa4e-4982-ab04-ad8e9635aa91.arff`
#
#
# ## 7. Perform evaluation
#
#
# Generation of most frequent values (baseline)
# R script
#
#
#
# ## 7.1. NCBI training, NCBI testing (free text)
# Restore backup of rules:
# ```json
# POST _reindex
# {
#   "source": {
#     "index": "cedar-value-recommender_backup-ncbi"
#   }
#   "dest": {
#     "index": "cedar-value-recommender"
#   }
# }
# ```
#
# main parameters used (see arm_constants.py):
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_USE_ANNOTATED_VALUES = False
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
# Execution time:  8748.737908124924 seconds
#
# ## 7.2. NCBI training, EBI testing (free text)
#
# main parameters used (see arm_constants.py):
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_USE_ANNOTATED_VALUES = False
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
# Execution time:  10036.864538908005 seconds
#
# ## 7.3. EBI training, EBI testing (free text)
#
# Restore backup of rules:
# ```json
# POST _reindex
# {
#   "source": {
#     "index": "cedar-value-recommender_backup-ncbi"
#   }
#   "dest": {
#     "index": "cedar-value-recommender"
#   }
# }
# ```
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_USE_ANNOTATED_VALUES = False
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  10676.317619085312 seconds
#
#
# ## 7.4. EBI training, NCBI testing (free text)
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_USE_ANNOTATED_VALUES = False
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  9867.484709978104 seconds
#
# ## 7.5. NCBI training, NCBI testing (annotated)
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  6836 seconds
# ## 7.6. NCBI training, EBI testing (annotated)
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  7860.066431045532 seconds
#
# ## 7.7. EBI training, EBI testing (annotated)
# ```json
# POST _reindex
# {
#   "dest": {
#     "index": "cedar-value-recommender"
#   },
#   "source": {
#     "index": "cedar-value-recommender_backup-ebi-annotated"
#   }
# }
# ```
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  7926.45552110672 seconds
#
# ## 7.8. EBI training, NCBI testing (annotated)
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = False
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  7181.8355939388275 seconds
#
#
# ## 7.9. NCBI training, NCBI testing (annotated, using mappings)
#
# Enable mappings in the value recommender server (constants file)
#
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = True
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
# Execution time:  6901.707034826279 seconds
#
# ## 7.10. NCBI training, EBI testing (annotated, using mappings)
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = True
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
# ---->
#
# ## 7.11. EBI training, EBI testing (annotated, using mappings)
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = True
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  6688.167499065399 seconds
#
#
# ## 7.12. EBI training, NCBI testing (annotated, using mappings)
#
# ```
# EVALUATION_TRAINING_DB = BIOSAMPLES_DB.EBI
# EVALUATION_TESTING_DB = BIOSAMPLES_DB.NCBI
# EVALUATION_USE_ANNOTATED_VALUES = True
# EVALUATION_EXTEND_URIS_WITH_MAPPINGS = True
# EVALUATION_MAX_NUMBER_INSTANCES = 20000
# EVALUATION_CEDAR_API_KEY = '<my_CEDAR_apiKey>'
# ```
#
# Execution time:  7615.736355066299 seconds
